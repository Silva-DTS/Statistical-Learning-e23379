# %% [markdown]
# <a href="https://colab.research.google.com/github/Silva-DTS/Statistical-Learning-e23379/blob/main/conditional_expectation_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Q1) Prediction of fraudulent transactions

# %% [markdown]
# A bank monitors credit-card transactions for possible fraud.
#
# For each transaction, let the sample space be
#
# $$
# \Omega=\{\omega_1,\omega_2,\omega_3,\omega_4\},
# $$
#
# where:
#
# * $\omega_1$: low-risk customer, legitimate transaction,
# * $\omega_2$: low-risk customer, fraudulent transaction,
# * $\omega_3$: high-risk customer, legitimate transaction,
# * $\omega_4$: high-risk customer, fraudulent transaction.
#
# Assume the probabilities are
#
# $$
# P(\{\omega_1\})=0.50,\qquad
# P(\{\omega_2\})=0.10,\qquad
# P(\{\omega_3\})=0.20,\qquad
# P(\{\omega_4\})=0.20.
# $$
#
# Let $X:\Omega\to\mathbb R$ denote the fraud indicator:
#
# $$
# X(\omega_1)=0,\qquad
# X(\omega_2)=1,\qquad
# X(\omega_3)=0,\qquad
# X(\omega_4)=1.
# $$
#
# Thus $X=1$ means the transaction is fraudulent, and $X=0$ means it is legitimate.
#
# Now suppose the bank does not observe the full outcome $\omega$, but only the customer's risk class. Define $Y:\Omega\to\mathbb R$ by
#
# $$
# Y(\omega_1)=0,\qquad
# Y(\omega_2)=0,\qquad
# Y(\omega_3)=1,\qquad
# Y(\omega_4)=1.
# $$
#
# Thus:
#
# * $Y=0$ means “low-risk customer,”
# * $Y=1$ means “high-risk customer.”
#
# Answer the following.
#
# 1. Write down the probability space $(\Omega,\mathfrak F,P)$, where $\mathfrak F=\mathfrak P(\Omega)$.
#
# 2. Compute the $\sigma$-algebra generated by $Y$, namely $\sigma(Y)$.
#
# 3. Explain why $E[X\mid Y]$ must be $\sigma(Y)$-measurable, and therefore must be constant on the sets $\{ \omega_1,\omega_2\}$ and $\{\omega_3,\omega_4\}$.
#
# 4. Compute $E[X\mid Y]$ explicitly and show that
#
# $$
# E[X\mid Y]= \frac{1}{6} \mathbb{1}_{\{Y=0\}} + \frac{1}{2} \mathbb{1}_{\{Y=1\}}
# $$
#
# 5. Verify the defining property of conditional expectation by checking that for every set $A\in\sigma(Y)$,
#
# $$
# \int_A E[X\mid Y]\,dP=\int_A X\,dP.
# $$
#
# 6. Find the Conditional PMF $p_{X|Y}(x \mid y)$.
#
# 7. Verify the identity:
# $$\mathbb{E}[X\mid Y=y] = \sum_{x \in \{0,1\}} x \cdot p_{X|Y}(x \mid y)$$.
#
# 8. Calculate the **Mean Square Error (MSE)**
#
# 9. How would the **Mean Square Error (MSE)** change if the bank decided to ignore the customer risk class $Y$ and instead used the global average fraud rate ($E[X] = 0.30$) as a constant estimate for every transaction? Calculate this error and explain its relationship to the **Law of Total Variance**.
#
# 10. Using the joint distribution of $(X, Y)$ derived from the sample space:
#
#     a) Compute the entropy $H(X)$, representing the bank's initial uncertainty regarding fraud.
#
#     b) Compute the conditional entropy $H(X \mid Y)$, representing the uncertainty remaining after the customer's risk class is revealed.
#
#     c) Calculate the Mutual Information $I(X; Y)$.
#
#     d) Based on these values, what percentage of the total uncertainty about fraud is removed by knowing the customer's risk class?

# %% [markdown]
# #### Answer
# 1. Sample space:
#
# $$
# \Omega=\{\omega_1,\omega_2,\omega_3,\omega_4\}
# $$
#
#
# - $\omega_1$: low-risk legitimate transaction
# - $\omega_2$: low-risk fraudulent transaction
# - $\omega_3$: high-risk legitimate transaction
# - $\omega_4$: high-risk fraudulent transaction
#
# Sigma algebra:
#
# $$
# \mathcal{F}=\mathcal{P}(\Omega)
# $$
#
# The probability measure:
#
# $$
# P(\omega_1)=0.50
# $$
#
# $$
# P(\omega_2)=0.10
# $$
#
# $$
# P(\omega_3)=0.20
# $$
#
# $$
# P(\omega_4)=0.20
# $$
#
# The $\sigma$-algebra $\mathcal{F}$ is the power set $\mathcal{P}(\Omega)$, which contains all $2^4 = 16$ possible subsets of $\Omega$:
#
# $$
# \mathcal{F} =
# \{
# \emptyset,
# \{\omega_1\},
# \{\omega_2\},
# \{\omega_3\},
# \{\omega_4\},
# \{\omega_1,\omega_2\},
# \{\omega_1,\omega_3\},
# \{\omega_1,\omega_4\},
# \{\omega_2,\omega_3\},
# \{\omega_2,\omega_4\},
# \{\omega_3,\omega_4\},
# \{\omega_1,\omega_2,\omega_3\},
# \{\omega_1,\omega_2,\omega_4\},
# \{\omega_1,\omega_3,\omega_4\},
# \{\omega_2,\omega_3,\omega_4\},
# \Omega
# \}
# $$
# <br>
# 2. Since:
#
# $$
# Y(\omega_1)=Y(\omega_2)=0
# $$
#
# and
#
# $$
# Y(\omega_3)=Y(\omega_4)=1
# $$
#
# the partition induced by $Y$ is:
#
# $$
# \{\omega_1,\omega_2\}, \quad \{\omega_3,\omega_4\}
# $$
#
# Thus:
#
# $$
# \sigma(Y)=
# \{
# \emptyset,
# \Omega,
# \{\omega_1,\omega_2\},
# \{\omega_3,\omega_4\}
# \}
# $$
# <br>
# 3. Since:
#
# $$
# Y(\omega_1)=Y(\omega_2)=0
# $$
#
# and
#
# $$
# Y(\omega_3)=Y(\omega_4)=1
# $$
#
# the partition induced by $Y$ is:
#
# $$
# \{\omega_1,\omega_2\}, \quad \{\omega_3,\omega_4\}
# $$
#
# Thus:
#
# $$
# \sigma(Y)=
# \{
# \emptyset,
# \Omega,
# \{\omega_1,\omega_2\},
# \{\omega_3,\omega_4\}
# \}
# $$
# <br>
# 4. Case 1: $Y=0$
#
# $$
# P(Y=0)=0.50+0.10=0.60
# $$
#
# Then:
#
# $$
# E[X|Y=0]
# =
# P(X=1|Y=0)
# $$
#
# $$
# =
# \frac{0.10}{0.60}
# $$
#
# $$
# =
# \frac16
# $$
#
# <br>
#
# Case 2: $Y=1$
#
# $$
# P(Y=1)=0.20+0.20=0.40
# $$
#
# Then:
#
# $$
# E[X|Y=1]
# =
# P(X=1|Y=1)
# $$
#
# $$
# =
# \frac{0.20}{0.40}
# $$
#
# $$
# =
# \frac12
# $$
#
# Therefore:
#
# $$
# E[X|Y]
# =
# \frac16 1_{\{Y=0\}}
# +
# \frac12 1_{\{Y=1\}}
# $$
# <br>
# 5. Take:
#
# $$
# A=\{\omega_1,\omega_2\}
# $$
#
# Then:
#
# $$
# \int_A E[X|Y]\,dP
# =
# \frac16(0.60)
# =
# 0.10
# $$
#
# and:
#
# $$
# \int_A X\,dP
# =
# 1(0.10)+0(0.50)
# =
# 0.10
# $$
#
# Similarly for:
#
# $$
# A=\{\omega_3,\omega_4\}
# $$
#
# $$
# \int_A E[X|Y]\,dP
# =
# \frac12(0.40)
# =
# 0.20
# $$
#
# and:
#
# $$
# \int_A X\,dP
# =
# 1(0.20)+0(0.20)
# =
# 0.20
# $$
#
# Hence it is verified.
# <br>
# 6. For $Y=0$
#
# $$
# p_{X|Y}(0|0)
# =
# \frac{0.50}{0.60}
# =
# \frac56
# $$
#
# $$
# p_{X|Y}(1|0)
# =
# \frac{0.10}{0.60}
# =
# \frac16
# $$
#
# <br> For $Y=1$
#
# $$
# p_{X|Y}(0|1)
# =
# \frac{0.20}{0.40}
# =
# \frac12
# $$
#
# $$
# p_{X|Y}(1|1)
# =
# \frac{0.20}{0.40}
# =
# \frac12
# $$
# <br>
#
# 7. For $Y=0$:
#
# $$
# E[X|Y=0]
# =
# 0\left(\frac56\right)
# +
# 1\left(\frac16\right)
# =
# \frac16
# $$
#
# For $Y=1$:
#
# $$
# E[X|Y=1]
# =
# 0\left(\frac12\right)
# +
# 1\left(\frac12\right)
# =
# \frac12
# $$
# <br>
#
# 8.
# Using:
#
# $$
# MSE=E[(X-E[X|Y])^2]
# $$
#
# We compute:
#
# $$
# Var(X|Y=0)
# =
# \frac16\left(\frac56\right)
# =
# \frac5{36}
# $$
#
# $$
# Var(X|Y=1)
# =
# \frac12\left(\frac12\right)
# =
# \frac14
# $$
#
# Thus:
#
# $$
# MSE
# =
# 0.60\left(\frac5{36}\right)
# +
# 0.40\left(\frac14\right)
# $$
#
# $$
# =
# 0.0833+0.10
# $$
#
# $$
# MSE\approx0.1833
# $$
# <br>
#
# 9. The global fraud rate is:
#
# $$
# E[X]
# =
# 0(0.70)+1(0.30)
# =
# 0.30
# $$
#
# If the bank ignores $Y$, then:
#
# $$
# MSE=Var(X)
# $$
#
# Since $X$ is Bernoulli:
#
# $$
# Var(X)=0.30(0.70)
# $$
#
# $$
# Var(X)=0.21
# $$
#
# Hence,
#
# $$
# 0.21>0.1833
# $$
#
# Therefore, using customer risk class improves prediction accuracy.
#
# This illustrates the Law of Total Variance:
#
# $$
# Var(X)
# =
# E[Var(X|Y)]
# +
# Var(E[X|Y])
# $$
# <br>
#
# 10. (a) Entropy of $X$
#
# $$
# H(X)
# =
# -0.7\log_2(0.7)
# -0.3\log_2(0.3)
# $$
#
# $$
# H(X)\approx0.881 \text{ bits}
# $$
#
# <br> (b) Conditional Entropy
#
# For $Y=0$:
#
# $$
# H(X|Y=0)
# =
# -\frac56\log_2\left(\frac56\right)
# -\frac16\log_2\left(\frac16\right)
# $$
#
# $$
# H(X|Y=0)\approx0.650
# $$
#
# For $Y=1$:
#
# $$
# H(X|Y=1)=1
# $$
#
# Thus:
#
# $$
# H(X|Y)
# =
# 0.60(0.650)+0.40(1)
# $$
#
# $$
# H(X|Y)\approx0.790
# $$
#
# <br>(c) Mutual Information
#
# $$
# I(X;Y)
# =
# H(X)-H(X|Y)
# $$
#
# $$
# =
# 0.881-0.790
# $$
#
# $$
# I(X;Y)\approx0.091 \text{ bits}
# $$
#
# <br>(d) Percentage of Uncertainty Removed
#
# $$
# \frac{I(X;Y)}{H(X)}\times100
# $$
#
# $$
# =
# \frac{0.091}{0.881}\times100
# $$
#
# $$
# \approx10.3\%
# $$
#
# hence, knowing the customer's risk class removes approximately 10.3% of the uncertainty regarding fraud.

# %% [markdown]
# # Q2) Conditional Density of the Multivariate Gaussian

# %% [markdown]
# Let $\mathbf{Z}$ be the concatenated random matrix
# $\mathbf{Z} = \begin{bmatrix} \mathbf{X} \\ \mathbf{Y} \end{bmatrix} \in \mathbb{R}^{n+m}$.
#
#
# The random variable $\mathbf{Z}$ is said to have a **joint multivariate normal distribution** if every linear combination of its components follows a univariate normal distribution.
#
# For $\mathbf{Z}$ to possess a **joint density function** (meaning its distribution is absolutely continuous with respect to the Lebesgue measure on $\mathbb{R}^{n+m}$), its covariance matrix must be non-singular (positive definite).
#
#
# The joint density function $f_{\mathbf{X}, \mathbf{Y}}(\mathbf{z})$ for $\mathbf{z} \in \mathbb{R}^{n+m}$ is given by:
#
# $$f_{\mathbf{X}, \mathbf{Y}}(\mathbf{z}) = \frac{1}{\sqrt{(2\pi)^{n+m} |\boldsymbol{\Sigma}|}} \exp\left( -\frac{1}{2} (\mathbf{z} - \boldsymbol{\mu})^T \boldsymbol{\Sigma}^{-1} (\mathbf{z} - \boldsymbol{\mu}) \right).$$
#
# Here:
#
# * **Mean ($\boldsymbol{\mu}$):** $\boldsymbol{\mu} = E[\mathbf{Z}] = \begin{bmatrix} \boldsymbol{\mu}_X \\ \boldsymbol{\mu}_Y \end{bmatrix} \in \mathbb{R}^{n+m}$, where $\boldsymbol{\mu}_X \in \mathbb{R}^n$ and $\boldsymbol{\mu}_Y \in \mathbb{R}^m$.
# * **Covariance Matrix ($\boldsymbol{\Sigma}$):** A symmetric, positive definite matrix $\boldsymbol{\Sigma} \in \mathbb{R}^{(n+m) \times (n+m)}$ partitioned as:
# $$\boldsymbol{\Sigma} = \begin{bmatrix} \boldsymbol{\Sigma}_{XX} & \boldsymbol{\Sigma}_{XY} \\ \boldsymbol{\Sigma}_{YX} & \boldsymbol{\Sigma}_{YY} \end{bmatrix}$$
#     * $\boldsymbol{\Sigma}_{XX} = \text{Var}(\mathbf{X})$ (size $n \times n$)
#     * $\boldsymbol{\Sigma}_{YY} = \text{Var}(\mathbf{Y})$ (size $m \times m$)
#     * $\boldsymbol{\Sigma}_{XY} = \text{Cov}(\mathbf{X}, \mathbf{Y}) = \boldsymbol{\Sigma}_{YX}^T$ (size $n \times m$)
# * **Determinant ($|\boldsymbol{\Sigma}|$):** The normalization factor ensuring the total integral is 1.
#
# 1. Show that the conditional distribution is given by $f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y})$
#
# $$f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y}) = \frac{1}{\sqrt{(2\pi)^n |\mathbf{S}_{XX}|}} \exp\left( -\frac{1}{2} (\mathbf{x} - \boldsymbol{\mu}^*)^T \boldsymbol{\Sigma}_{X\mid Y}^{-1} (\mathbf{x} - \boldsymbol{\mu}^*) \right),$$
# where
# * $\boldsymbol{\Sigma}_{X\mid Y} = \boldsymbol{\Sigma}_{XX} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}$
# * $\boldsymbol{\mu}^* = \boldsymbol{\mu}_x + \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y} - \boldsymbol{\mu}_y)$

# %% [markdown]
# #### Answer
# 1. Let
#
# $$
# \mathbf{Z}=
# \begin{bmatrix}
# \mathbf{X}\\
# \mathbf{Y}
# \end{bmatrix}
# \sim N(\mu,\Sigma)
# $$
#
# where
#
# $$
# \mu=
# \begin{bmatrix}
# \mu_X\\
# \mu_Y
# \end{bmatrix}
# $$
#
# and
#
# $$
# \Sigma=
# \begin{bmatrix}
# \Sigma_{XX} & \Sigma_{XY}\\
# \Sigma_{YX} & \Sigma_{YY}
# \end{bmatrix}
# $$
#
# The joint density is:
#
# $$
# f_{X,Y}(x,y)
# =
# \frac{
# 1
# }{
# \sqrt{(2\pi)^{n+m}|\Sigma|}
# }
# \exp\left(
# -\frac12
# (z-\mu)^T
# \Sigma^{-1}
# (z-\mu)
# \right)
# $$
#
# where
#
# $$
# z=
# \begin{bmatrix}
# x\\
# y
# \end{bmatrix}
# $$
#
# The conditional density is defined by:
#
# $$
# f_{X|Y}(x|y)
# =
# \frac{
# f_{X,Y}(x,y)
# }{
# f_Y(y)
# }
# $$
#
# For a jointly Gaussian vector, completing the square in the exponent gives another Gaussian density.
#
# Hence:
#
# $$
# X|Y=y
# \sim
# N(\mu^*,\Sigma_{X|Y})
# $$
#
# where
#
# $$
# \mu^*
# =
# \mu_X
# +
# \Sigma_{XY}
# \Sigma_{YY}^{-1}
# (y-\mu_Y)
# $$
#
# and
#
# $$
# \Sigma_{X|Y}
# =
# \Sigma_{XX}
# -
# \Sigma_{XY}
# \Sigma_{YY}^{-1}
# \Sigma_{YX}
# $$
#
# Therefore,
#
# $$
# f_{X|Y}(x|y)
# =
# \frac{
# 1
# }{
# \sqrt{
# (2\pi)^n
# |\Sigma_{X|Y}|
# }
# }
# \exp\left(
# -\frac12
# (x-\mu^*)^T
# \Sigma_{X|Y}^{-1}
# (x-\mu^*)
# \right)
# $$
#
# Thus, the conditional distribution of a multivariate Gaussian is again Gaussian with mean
#
# $$
# \mu^*
# =
# \mu_X
# +
# \Sigma_{XY}
# \Sigma_{YY}^{-1}
# (y-\mu_Y)
# $$
#
# and covariance
#
# $$
# \Sigma_{X|Y}
# =
# \Sigma_{XX}
# -
# \Sigma_{XY}
# \Sigma_{YY}^{-1}
# \Sigma_{YX}
# $$

# %% [markdown]
# # Q3) Continuous Fault Monitoring of a Spindle Motor

# %% [markdown]
# A factory monitors the health of a high-speed CNC spindle. The critical variable is the **Internal Temperature ($X$)**, but because the motor is sealed, they can only observe the **Total Spindle Power ($Y$)**.
#
# **The Setup:**
# 1.  **Hidden Temperature ($X$):** The standardized temperature deviation follows a standard normal distribution:
#     $$X \sim \mathscr{N}(0, 1)$$
# 2.  **Mechanical Load ($Q$):** The torque required to cut material creates "noise" in the power reading. It is independent of temperature and follows:
#     $$Q \sim \mathscr{N}(0, 4)$$
# 3.  **The Measurement ($Y$):** The power sensor $Y$ measures the combined effect of thermal load and mechanical torque:
# $$Y = X + Q$$
#
# ---
#
# **Answer the followings:**
#
# **1. Joint Distribution**
# Identify the distribution of the random varaible $(X, Y)$.
# * Show that $Y \sim \mathscr{N}(0, 5)$.
# * Find the covariance $\text{Cov}(X, Y)$.
#
# **2. Information Geometry**
# Explain why $X$ is **not** $\sigma(Y)$-measurable. In practical terms, if the power meter shows $Y = 5$, why can't the engineer know for certain if the motor is overheating ($X$ is high) or if the material being cut is simply very hard ($Q$ is high)?
#
# **3. Conditional Expectation (The Best Estimate)**
# Compute the conditional expectation $E[X \mid Y]$.
# * Using the property for joint normals: $E[X \mid Y = y] = \mu_X + \frac{\text{Cov}(X,Y)}{\text{Var}(Y)}(y - \mu_Y)$.
# * Express this as a "signal-to-total-variance" ratio.
#
# **4. Verification of the Residual**
# Let $\widehat{X} = E[X \mid Y]$. Define the estimation error (residual) as $Z = X - \widehat{X}$.
# * Prove that $E[Z] = 0$.
# * Verify that the error $Z$ is uncorrelated with the observation $Y$ (the Orthogonality Principle).
#
# **5. Information Theory: Differential Entropy**
# * Compute the differential entropy $h(X)$.
# * Compute the conditional differential entropy $h(X \mid Y)$.
# * *Note: The variance of the conditional distribution $(X \mid Y=y)$ is given by $\sigma_{X|Y}^2 = \sigma_X^2 - \frac{\text{Cov}(X,Y)^2}{\text{Var}(Y)}$.*
#
# **6. Mutual Information**
# Calculate $I(X; Y) = h(X) - h(X \mid Y)$.
# * What percentage of the "uncertainty" about the temperature is removed by observing the power meter?
# * How would this change if the mechanical noise $Q$ had a variance of $100$ instead of $4$?
#
# **7. Diagnostic Interpretation**
# The factory manager says: *"Since $Y = X + Q$, our best estimate of temperature should just be $Y$ itself."*
# Using your result from Question 3, explain why $Y$ is a **biased** estimator of $X$ and why $E[X \mid Y]$ "shrinks" the measurement toward the mean (zero).

# %% [markdown]
# #### Answer
# 1. Joint Distribution
#
# Given:
#
# $$
# X \sim \mathcal{N}(0,1)
# $$
#
# $$
# Q \sim \mathcal{N}(0,4)
# $$
#
# with $X$ and $Q$ independent, and
#
# $$
# Y=X+Q
# $$
#
# Since the sum of independent Gaussian random variables is Gaussian:
#
# $$
# Y \sim \mathcal{N}(0,1+4)
# $$
#
# Therefore:
#
# $$
# Y \sim \mathcal{N}(0,5)
# $$
#
# The mean vector of $(X,Y)$ is:
#
# $$
# \mu=
# \begin{bmatrix}
# 0\\
# 0
# \end{bmatrix}
# $$
#
# Now compute covariance:
#
# $$
# \text{Cov}(X,Y)
# =
# \text{Cov}(X,X+Q)
# $$
#
# $$
# =
# \text{Var}(X)+\text{Cov}(X,Q)
# $$
#
# Since $X$ and $Q$ are independent:
#
# $$
# \text{Cov}(X,Q)=0
# $$
#
# Thus:
#
# $$
# \text{Cov}(X,Y)=1
# $$
#
# Hence the covariance matrix is:
#
# $$
# \Sigma=
# \begin{bmatrix}
# 1 & 1\\
# 1 & 5
# \end{bmatrix}
# $$
#
# Therefore:
#
# $$
# (X,Y)\sim\mathcal{N}
# \left(
# \begin{bmatrix}
# 0\\
# 0
# \end{bmatrix},
# \begin{bmatrix}
# 1 & 1\\
# 1 & 5
# \end{bmatrix}
# \right)
# $$
#
# ---
#
# 2. Information Geometry
#
# The variable $X$ is not $\sigma(Y)$-measurable because observing $Y$ does not uniquely determine $X$.
#
# Since:
#
# $$
# Y=X+Q
# $$
#
# many different pairs $(X,Q)$ can produce the same value of $Y$.
#
# For example, if:
#
# $$
# Y=5
# $$
#
# then possible combinations include:
#
# $$
# X=5,\quad Q=0
# $$
#
# or
#
# $$
# X=2,\quad Q=3
# $$
#
# or
#
# $$
# X=1,\quad Q=4
# $$
#
# Therefore, the engineer cannot know whether the large power reading is caused by overheating or by heavy cutting load.
#
# ---
#
# 3. Conditional Expectation
#
# Using the joint Gaussian formula:
#
# $$
# E[X|Y=y]
# =
# \mu_X
# +
# \frac{\text{Cov}(X,Y)}{\text{Var}(Y)}
# (y-\mu_Y)
# $$
#
# Since:
#
# $$
# \mu_X=0
# $$
#
# $$
# \mu_Y=0
# $$
#
# $$
# \text{Cov}(X,Y)=1
# $$
#
# $$
# \text{Var}(Y)=5
# $$
#
# we obtain:
#
# $$
# E[X|Y=y]
# =
# \frac15 y
# $$
#
# Therefore:
#
# $$
# E[X|Y]
# =
# \frac15 Y
# $$
#
# The ratio:
#
# $$
# \frac{\text{Cov}(X,Y)}{\text{Var}(Y)}
# =
# \frac15
# $$
#
# is called the signal-to-total-variance ratio.
#
# Only one part of the observed variance comes from temperature; the remaining variance comes from mechanical noise.
#
# ---
#
# 4. Verification of the Residual
#
# Define:
#
# $$
# \widehat{X}=E[X|Y]=\frac15Y
# $$
#
# The residual error is:
#
# $$
# Z=X-\widehat{X}
# $$
#
# Thus:
#
# $$
# Z=X-\frac15Y
# $$
#
# Mean of the Residual:
#
# $$
# E[Z]
# =
# E[X]-\frac15E[Y]
# $$
#
# Since:
#
# $$
# E[X]=0,\quad E[Y]=0
# $$
#
# we get:
#
# $$
# E[Z]=0
# $$
#
# Orthogonality Principle:
#
# $$
# \text{Cov}(Z,Y)
# =
# \text{Cov}\left(X-\frac15Y,Y\right)
# $$
#
# $$
# =
# \text{Cov}(X,Y)-\frac15\text{Var}(Y)
# $$
#
# $$
# =
# 1-\frac15(5)
# $$
#
# $$
# =0
# $$
#
# Hence the residual error is uncorrelated with the observation $Y$.
#
# ---
#
# 5. Differential Entropy
#
# For a Gaussian random variable:
#
# $$
# h(X)=\frac12\ln(2\pi e\sigma^2)
# $$
#
# Since:
#
# $$
# \sigma_X^2=1
# $$
#
# we obtain:
#
# $$
# h(X)=\frac12\ln(2\pi e)
# $$
#
# $$
# h(X)\approx1.419
# $$
#
# Conditional Entropy:
#
# The conditional variance is:
#
# $$
# \sigma_{X|Y}^2
# =
# \sigma_X^2
# -
# \frac{\text{Cov}(X,Y)^2}{\text{Var}(Y)}
# $$
#
# Substituting values:
#
# $$
# \sigma_{X|Y}^2
# =
# 1-\frac{1^2}{5}
# $$
#
# $$
# =
# \frac45
# $$
#
# Therefore:
#
# $$
# h(X|Y)
# =
# \frac12\ln\left(2\pi e\frac45\right)
# $$
#
# $$
# h(X|Y)\approx1.307
# $$
#
# ---
#
# 6. Mutual Information
#
# Mutual information is:
#
# $$
# I(X;Y)=h(X)-h(X|Y)
# $$
#
# Thus:
#
# $$
# I(X;Y)
# =
# \frac12\ln\left(\frac54\right)
# $$
#
# $$
# I(X;Y)\approx0.112
# $$
#
# Percentage of Uncertainty Removed:
#
# $$
# \frac{I(X;Y)}{h(X)}\times100
# $$
#
# $$
# =
# \frac{0.112}{1.419}\times100
# $$
#
# $$
# \approx7.9\%
# $$
#
# Thus, observing the power meter removes only about $7.9\%$ of the uncertainty about temperature.
#
# If Noise Variance Becomes 100:
#
# Now:
#
# $$
# Q\sim\mathcal{N}(0,100)
# $$
#
# Then:
#
# $$
# Y\sim\mathcal{N}(0,101)
# $$
#
# The signal-to-total-variance ratio becomes:
#
# $$
# \frac1{101}
# $$
#
# which is very small.
#
# Hence:
#
# $$
# E[X|Y]=\frac1{101}Y
# $$
#
# and the mutual information becomes much smaller.
#
# Therefore, the observation provides very little information about temperature when the noise is extremely large.
#
# ---
#
# 7. Diagnostic Interpretation
#
# The manager claims that the best estimate of temperature is simply:
#
# $$
# X\approx Y
# $$
#
# However:
#
# $$
# Y=X+Q
# $$
#
# contains both the temperature signal and mechanical noise.
#
# Since the noise variance is large, directly using $Y$ exaggerates the true temperature deviation.
#
# The optimal estimator is:
#
# $$
# E[X|Y]=\frac15Y
# $$
#
# not $Y$ itself.
#
# This estimator shrinks the observation toward zero because only part of the observed power comes from temperature, while the rest comes from random mechanical load.
#
# Hence, conditional expectation automatically filters out part of the noise and gives the minimum mean square error estimate.
