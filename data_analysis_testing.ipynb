# %% [markdown]
# <a href="https://colab.research.google.com/github/Silva-DTS/Statistical-Learning-e23379/blob/main/data_analysis_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json, csv
import pandas as pd
# import numpy as np
# import scipy.stats
# import seaborn as sns
# import matplotlib.pyplot as plt
# import networkx as nx
# import graphviz
# from IPython.display import display, Image, HTML

# from pydantic import BaseModel, ValidationError, field_validator
# from typing import Optional

# %%
# !pip install "git+https://github.com/Silva-DTS/Statistical-Learning-e23379.git"
# Out:
# ...
#   Cloning https://github.com/Silva-DTS/Statistical-Learning-e23379.git to /tmp/pip-req-build-uxg6jt0q
#   Running command git clone --filter=blob:none --quiet https://github.com/Silva-DTS/Statistical-Learning-e23379.git /tmp/pip-req-build-uxg6jt0q
#   Resolved https://github.com/Silva-DTS/Statistical-Learning-e23379.git to commit 21024398333fa9779d59250b49a33dcd517cae18
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for data-analysis-tool: filename=data_analysis_tool-0.1.0-py3-none-any.whl size=1410 sha256=c139fc5e35dfe4b156eb4ac49a3e4d6263ab201d6205bce3ac743695ae55fd25
#   Stored in directory: /tmp/pip-ephem-wheel-cache-02ise5kn/wheels/85/97/3b/1a4d37a110f8643e267a0cc1dbfcdc7760a32e9975446cf265
# Successfully built data-analysis-tool
# ...

# %%
from data_analysis.core import DataInspector

# %%
inspector = DataInspector()
# Out:
# Statistical Learning Toolkit Loaded Successfully!
